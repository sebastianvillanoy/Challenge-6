# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
from config import weather_api_key
from datetime import datetime
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | yulara
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | lima
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | slave lake
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | merville
# Processing Record 12 of Set 1 | lubao
# Processing Record 13 of Set 1 | chapais
# Processing Record 14 of Set 1 | ahipara
# Processing Record 15 of Set 1 | saskylakh
# Processing Record 16 of Set 1 | makakilo city
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | broome
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | pevek
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | victoria
# Processing Record 24 of Set 1 | camacha
# Processing Record 25 of Set 1 | rawah
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | hofn
# Processing Record 29 of Set 1 | yakeshi
# Processing Record 30 of Set 1 | torbay
# Processing Record 31 of Set 1 | amethi
# Processing Record 32 of Set 1 | fort william
# Processing Record 33 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 1 | empalme
# Processing Record 35 of Set 1 | buraydah
# Processing Record 36 of Set 1 | coihaique
# Processing Record 37 of Set 1 | te anau
# Processing Record 38 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 1 | port-gentil
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | orgun
# City not found. Skipping...
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | norman wells
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | carutapera
# Processing Record 48 of Set 1 | yeppoon
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | praya
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | sciacca
# Processing Record 4 of Set 2 | kununurra
# Processing Record 5 of Set 2 | tiznit
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | grand gaube
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 2 | bengkulu
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | mahajanga
# Processing Record 13 of Set 2 | kawalu
# Processing Record 14 of Set 2 | turukhansk
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | lebu
# Processing Record 19 of Set 2 | impfondo
# Processing Record 20 of Set 2 | blackwater
# Processing Record 21 of Set 2 | bismarck
# Processing Record 22 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 2 | bhum
# Processing Record 24 of Set 2 | hithadhoo
# Processing Record 25 of Set 2 | keti bandar
# Processing Record 26 of Set 2 | voyvozh
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | pangkalanbuun
# Processing Record 29 of Set 2 | hambantota
# Processing Record 30 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | namie
# Processing Record 35 of Set 2 | mar del plata
# Processing Record 36 of Set 2 | lompoc
# Processing Record 37 of Set 2 | pompeu
# Processing Record 38 of Set 2 | pangai
# Processing Record 39 of Set 2 | warrnambool
# Processing Record 40 of Set 2 | rizhao
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | saint-philippe
# Processing Record 43 of Set 2 | tazovskiy
# Processing Record 44 of Set 2 | eirunepe
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | tucurui
# Processing Record 47 of Set 2 | nantucket
# Processing Record 48 of Set 2 | lake havasu city
# Processing Record 49 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 2 | anadyr
# Processing Record 1 of Set 3 | launceston
# Processing Record 2 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 3 | cape town
# Processing Record 4 of Set 3 | cherskiy
# Processing Record 5 of Set 3 | gympie
# Processing Record 6 of Set 3 | honningsvag
# Processing Record 7 of Set 3 | narsaq
# Processing Record 8 of Set 3 | tekeli
# Processing Record 9 of Set 3 | guerrero negro
# Processing Record 10 of Set 3 | kahului
# Processing Record 11 of Set 3 | vardo
# Processing Record 12 of Set 3 | albany
# Processing Record 13 of Set 3 | susehri
# Processing Record 14 of Set 3 | hilo
# Processing Record 15 of Set 3 | ekhabi
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | tommot
# Processing Record 18 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 3 | svetlyy
# Processing Record 20 of Set 3 | upernavik
# Processing Record 21 of Set 3 | san cristobal
# Processing Record 22 of Set 3 | vostok
# Processing Record 23 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 3 | pedasi
# Processing Record 25 of Set 3 | trelew
# Processing Record 26 of Set 3 | shingu
# Processing Record 27 of Set 3 | beringovskiy
# Processing Record 28 of Set 3 | san juan del cesar
# Processing Record 29 of Set 3 | elliot lake
# Processing Record 30 of Set 3 | namibe
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | airai
# Processing Record 34 of Set 3 | laguna
# Processing Record 35 of Set 3 | eydhafushi
# Processing Record 36 of Set 3 | hirado
# Processing Record 37 of Set 3 | puerto ayora
# Processing Record 38 of Set 3 | sisimiut
# Processing Record 39 of Set 3 | gornopravdinsk
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | new norfolk
# Processing Record 42 of Set 3 | quatre cocos
# Processing Record 43 of Set 3 | clyde river
# Processing Record 44 of Set 3 | lasa
# Processing Record 45 of Set 3 | xai-xai
# Processing Record 46 of Set 3 | batagay-alyta
# Processing Record 47 of Set 3 | hokitika
# Processing Record 48 of Set 3 | olinda
# Processing Record 49 of Set 3 | saint anthony
# Processing Record 50 of Set 3 | rudnaya pristan
# Processing Record 1 of Set 4 | svetlogorsk
# Processing Record 2 of Set 4 | kudahuvadhoo
# Processing Record 3 of Set 4 | nikolskoye
# Processing Record 4 of Set 4 | le port
# Processing Record 5 of Set 4 | sabang
# Processing Record 6 of Set 4 | tuatapere
# Processing Record 7 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 4 | durango
# Processing Record 9 of Set 4 | esmeraldas
# Processing Record 10 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 11 of Set 4 | helong
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | koumac
# Processing Record 14 of Set 4 | oranjemund
# Processing Record 15 of Set 4 | ponta do sol
# Processing Record 16 of Set 4 | katangli
# Processing Record 17 of Set 4 | vanino
# Processing Record 18 of Set 4 | kattivakkam
# Processing Record 19 of Set 4 | tanete
# Processing Record 20 of Set 4 | kandrian
# Processing Record 21 of Set 4 | provideniya
# Processing Record 22 of Set 4 | codrington
# Processing Record 23 of Set 4 | nanortalik
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | tiksi
# Processing Record 26 of Set 4 | lander
# Processing Record 27 of Set 4 | patan
# Processing Record 28 of Set 4 | maridi
# Processing Record 29 of Set 4 | mahebourg
# Processing Record 30 of Set 4 | thiruvananthapuram
# Processing Record 31 of Set 4 | lagoa
# Processing Record 32 of Set 4 | lata
# Processing Record 33 of Set 4 | inhambane
# Processing Record 34 of Set 4 | esperance
# Processing Record 35 of Set 4 | semnan
# Processing Record 36 of Set 4 | saint george
# Processing Record 37 of Set 4 | beaverlodge
# Processing Record 38 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 4 | talnakh
# Processing Record 40 of Set 4 | deputatskiy
# Processing Record 41 of Set 4 | charkhi dadri
# Processing Record 42 of Set 4 | bundaberg
# Processing Record 43 of Set 4 | rudnogorsk
# Processing Record 44 of Set 4 | pisco
# Processing Record 45 of Set 4 | sitka
# Processing Record 46 of Set 4 | cayenne
# Processing Record 47 of Set 4 | nokaneng
# Processing Record 48 of Set 4 | ancud
# Processing Record 49 of Set 4 | maxixe
# Processing Record 50 of Set 4 | solano
# Processing Record 1 of Set 5 | lengshuitan
# Processing Record 2 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 5 | montargis
# Processing Record 4 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 5 of Set 5 | port hardy
# Processing Record 6 of Set 5 | corinto
# Processing Record 7 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 5 | coahuayana
# Processing Record 9 of Set 5 | majene
# Processing Record 10 of Set 5 | neos pirgos
# City not found. Skipping...
# Processing Record 11 of Set 5 | athabasca
# Processing Record 12 of Set 5 | kyaikkami
# Processing Record 13 of Set 5 | buta
# Processing Record 14 of Set 5 | sorland
# Processing Record 15 of Set 5 | bluefield
# Processing Record 16 of Set 5 | joao pinheiro
# Processing Record 17 of Set 5 | bambous virieux
# Processing Record 18 of Set 5 | aksu
# Processing Record 19 of Set 5 | port elizabeth
# Processing Record 20 of Set 5 | xining
# Processing Record 21 of Set 5 | roald
# Processing Record 22 of Set 5 | ljubinje
# Processing Record 23 of Set 5 | isangel
# Processing Record 24 of Set 5 | tirumullaivasal
# Processing Record 25 of Set 5 | walvis bay
# Processing Record 26 of Set 5 | angoche
# Processing Record 27 of Set 5 | karaton
# Processing Record 28 of Set 5 | wamba
# Processing Record 29 of Set 5 | floro
# Processing Record 30 of Set 5 | cockburn town
# Processing Record 31 of Set 5 | morgan city
# Processing Record 32 of Set 5 | mehamn
# Processing Record 33 of Set 5 | waipawa
# Processing Record 34 of Set 5 | uri
# Processing Record 35 of Set 5 | sioux lookout
# Processing Record 36 of Set 5 | polessk
# Processing Record 37 of Set 5 | marsta
# Processing Record 38 of Set 5 | okhotsk
# Processing Record 39 of Set 5 | lavrentiya
# Processing Record 40 of Set 5 | lazaro cardenas
# Processing Record 41 of Set 5 | kruisfontein
# Processing Record 42 of Set 5 | fort nelson
# Processing Record 43 of Set 5 | vilhena
# Processing Record 44 of Set 5 | ogulin
# Processing Record 45 of Set 5 | apex
# Processing Record 46 of Set 5 | bonoua
# Processing Record 47 of Set 5 | hailar
# Processing Record 48 of Set 5 | semey
# Processing Record 49 of Set 5 | wa
# City not found. Skipping...
# Processing Record 50 of Set 5 | riyadh
# Processing Record 1 of Set 6 | xichang
# Processing Record 2 of Set 6 | severo-kurilsk
# Processing Record 3 of Set 6 | whitianga
# Processing Record 4 of Set 6 | tura
# Processing Record 5 of Set 6 | monte cristi
# City not found. Skipping...
# Processing Record 6 of Set 6 | skagen
# Processing Record 7 of Set 6 | wahiawa
# Processing Record 8 of Set 6 | durban
# Processing Record 9 of Set 6 | kathu
# Processing Record 10 of Set 6 | bhongir
# Processing Record 11 of Set 6 | fairbanks
# Processing Record 12 of Set 6 | ibiruba
# Processing Record 13 of Set 6 | iqaluit
# Processing Record 14 of Set 6 | jardim
# Processing Record 15 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 6 | leshukonskoye
# Processing Record 17 of Set 6 | arraial do cabo
# Processing Record 18 of Set 6 | langsa
# Processing Record 19 of Set 6 | castro
# Processing Record 20 of Set 6 | karakol
# Processing Record 21 of Set 6 | igarka
# Processing Record 22 of Set 6 | vila
# Processing Record 23 of Set 6 | faanui
# Processing Record 24 of Set 6 | longyearbyen
# Processing Record 25 of Set 6 | igrim
# Processing Record 26 of Set 6 | great yarmouth
# Processing Record 27 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 6 | diamantino
# Processing Record 29 of Set 6 | kindu
# Processing Record 30 of Set 6 | mayo
# Processing Record 31 of Set 6 | ixtapa
# Processing Record 32 of Set 6 | yagodnoye
# Processing Record 33 of Set 6 | balabac
# Processing Record 34 of Set 6 | katherine
# Processing Record 35 of Set 6 | methoni
# Processing Record 36 of Set 6 | taoudenni
# Processing Record 37 of Set 6 | bereda
# Processing Record 38 of Set 6 | liepaja
# Processing Record 39 of Set 6 | tofield
# Processing Record 40 of Set 6 | akureyri
# Processing Record 41 of Set 6 | barao de melgaco
# Processing Record 42 of Set 6 | churapcha
# Processing Record 43 of Set 6 | tabat
# Processing Record 44 of Set 6 | portobelo
# Processing Record 45 of Set 6 | mukhen
# Processing Record 46 of Set 6 | rokytne
# Processing Record 47 of Set 6 | shache
# Processing Record 48 of Set 6 | usinsk
# Processing Record 49 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 6 | marquette
# Processing Record 1 of Set 7 | kavieng
# Processing Record 2 of Set 7 | yazykovo
# Processing Record 3 of Set 7 | benguela
# Processing Record 4 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 7 | komsomolskiy
# Processing Record 6 of Set 7 | kanye
# Processing Record 7 of Set 7 | bathsheba
# Processing Record 8 of Set 7 | casper
# Processing Record 9 of Set 7 | kloulklubed
# Processing Record 10 of Set 7 | morros
# Processing Record 11 of Set 7 | boo
# Processing Record 12 of Set 7 | micheweni
# Processing Record 13 of Set 7 | alice springs
# Processing Record 14 of Set 7 | klyuchi
# Processing Record 15 of Set 7 | asau
# Processing Record 16 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 17 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 18 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 7 | haikou
# Processing Record 20 of Set 7 | gongzhuling
# Processing Record 21 of Set 7 | sur
# Processing Record 22 of Set 7 | isla vista
# Processing Record 23 of Set 7 | honiara
# Processing Record 24 of Set 7 | kurilsk
# Processing Record 25 of Set 7 | bethel
# Processing Record 26 of Set 7 | voh
# Processing Record 27 of Set 7 | chuy
# Processing Record 28 of Set 7 | luderitz
# Processing Record 29 of Set 7 | cabo san lucas
# Processing Record 30 of Set 7 | sinop
# Processing Record 31 of Set 7 | pital
# Processing Record 32 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 33 of Set 7 | saldanha
# Processing Record 34 of Set 7 | gold coast
# Processing Record 35 of Set 7 | qurayyat
# Processing Record 36 of Set 7 | sapa
# Processing Record 37 of Set 7 | souillac
# Processing Record 38 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 7 | dali
# Processing Record 40 of Set 7 | ucluelet
# Processing Record 41 of Set 7 | saint-joseph
# Processing Record 42 of Set 7 | berlevag
# Processing Record 43 of Set 7 | villa maria
# Processing Record 44 of Set 7 | chicama
# Processing Record 45 of Set 7 | balsas
# Processing Record 46 of Set 7 | muros
# Processing Record 47 of Set 7 | coyah
# Processing Record 48 of Set 7 | hamilton
# Processing Record 49 of Set 7 | lauria
# Processing Record 50 of Set 7 | nishihara
# Processing Record 1 of Set 8 | coquimbo
# Processing Record 2 of Set 8 | aljezur
# Processing Record 3 of Set 8 | zhigansk
# Processing Record 4 of Set 8 | adrar
# Processing Record 5 of Set 8 | belmonte
# Processing Record 6 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 8 | lorengau
# Processing Record 8 of Set 8 | praia
# Processing Record 9 of Set 8 | la ronge
# Processing Record 10 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 11 of Set 8 | meiganga
# Processing Record 12 of Set 8 | mount gambier
# Processing Record 13 of Set 8 | melbu
# Processing Record 14 of Set 8 | puri
# Processing Record 15 of Set 8 | tomatlan
# Processing Record 16 of Set 8 | massaguet
# Processing Record 17 of Set 8 | vanimo
# Processing Record 18 of Set 8 | caninde
# Processing Record 19 of Set 8 | newport
# Processing Record 20 of Set 8 | jacmel
# Processing Record 21 of Set 8 | killeen
# Processing Record 22 of Set 8 | kolpny
# Processing Record 23 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 8 | glenwood springs
# Processing Record 25 of Set 8 | puerto escondido
# Processing Record 26 of Set 8 | beloha
# Processing Record 27 of Set 8 | college
# Processing Record 28 of Set 8 | pacific grove
# Processing Record 29 of Set 8 | odweyne
# Processing Record 30 of Set 8 | gladstone
# Processing Record 31 of Set 8 | kerman
# Processing Record 32 of Set 8 | ramgarh
# Processing Record 33 of Set 8 | mayya
# Processing Record 34 of Set 8 | port blair
# Processing Record 35 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 36 of Set 8 | tukrah
# Processing Record 37 of Set 8 | bichena
# Processing Record 38 of Set 8 | nizwa
# Processing Record 39 of Set 8 | christchurch
# Processing Record 40 of Set 8 | kavaratti
# Processing Record 41 of Set 8 | russell
# Processing Record 42 of Set 8 | havoysund
# Processing Record 43 of Set 8 | fortuna
# Processing Record 44 of Set 8 | aklavik
# Processing Record 45 of Set 8 | strezhevoy
# Processing Record 46 of Set 8 | pleshanovo
# Processing Record 47 of Set 8 | birao
# Processing Record 48 of Set 8 | khuzhir
# Processing Record 49 of Set 8 | ust-nera
# Processing Record 50 of Set 8 | mareeba
# Processing Record 1 of Set 9 | tasiilaq
# Processing Record 2 of Set 9 | balkhash
# Processing Record 3 of Set 9 | salalah
# Processing Record 4 of Set 9 | pacifica
# Processing Record 5 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 6 of Set 9 | bardiyah
# Processing Record 7 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 8 of Set 9 | nome
# Processing Record 9 of Set 9 | valparaiso
# Processing Record 10 of Set 9 | rincon
# Processing Record 11 of Set 9 | mamakan
# Processing Record 12 of Set 9 | kaitangata
# Processing Record 13 of Set 9 | malartic
# Processing Record 14 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 9 | libreville
# Processing Record 16 of Set 9 | maceio
# Processing Record 17 of Set 9 | eenhana
# Processing Record 18 of Set 9 | zvishavane
# Processing Record 19 of Set 9 | shimoda
# Processing Record 20 of Set 9 | san jose del palmar
# Processing Record 21 of Set 9 | north bend
# Processing Record 22 of Set 9 | kikwit
# Processing Record 23 of Set 9 | villa union
# Processing Record 24 of Set 9 | nemuro
# Processing Record 25 of Set 9 | portlethen
# Processing Record 26 of Set 9 | ndele
# Processing Record 27 of Set 9 | yuxia
# Processing Record 28 of Set 9 | grabouw
# Processing Record 29 of Set 9 | vallenar
# Processing Record 30 of Set 9 | basoko
# Processing Record 31 of Set 9 | port hedland
# Processing Record 32 of Set 9 | saint-francois
# Processing Record 33 of Set 9 | kouango
# Processing Record 34 of Set 9 | mogadishu
# Processing Record 35 of Set 9 | sao felix do xingu
# Processing Record 36 of Set 9 | neiafu
# Processing Record 37 of Set 9 | mwinilunga
# Processing Record 38 of Set 9 | warren
# Processing Record 39 of Set 9 | vila velha
# Processing Record 40 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 9 | iskateley
# Processing Record 42 of Set 9 | tabas
# Processing Record 43 of Set 9 | coolum beach
# Processing Record 44 of Set 9 | sao joao do piaui
# Processing Record 45 of Set 9 | nuuk
# Processing Record 46 of Set 9 | nazas
# Processing Record 47 of Set 9 | yangjiang
# Processing Record 48 of Set 9 | nchelenge
# Processing Record 49 of Set 9 | sokolo
# Processing Record 50 of Set 9 | marsa matruh
# Processing Record 1 of Set 10 | pakxe
# Processing Record 2 of Set 10 | escarcega
# Processing Record 3 of Set 10 | mae sai
# Processing Record 4 of Set 10 | bairiki
# Processing Record 5 of Set 10 | jiwani
# Processing Record 6 of Set 10 | leningradskiy
# Processing Record 7 of Set 10 | los llanos de aridane
# Processing Record 8 of Set 10 | sinnamary
# Processing Record 9 of Set 10 | olafsvik
# Processing Record 10 of Set 10 | novaya ladoga
# Processing Record 11 of Set 10 | birin
# Processing Record 12 of Set 10 | sao filipe
# Processing Record 13 of Set 10 | evensk
# Processing Record 14 of Set 10 | lulea
# Processing Record 15 of Set 10 | safford
# Processing Record 16 of Set 10 | maltahohe
# Processing Record 17 of Set 10 | stutterheim
# Processing Record 18 of Set 10 | constitucion
# Processing Record 19 of Set 10 | champerico
# Processing Record 20 of Set 10 | maksatikha
# Processing Record 21 of Set 10 | dolores
# Processing Record 22 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 10 | nelson bay
# Processing Record 24 of Set 10 | kanelovskaya
# Processing Record 25 of Set 10 | nouakchott
# Processing Record 26 of Set 10 | tabou
# Processing Record 27 of Set 10 | la romana
# Processing Record 28 of Set 10 | ieper
# Processing Record 29 of Set 10 | shepsi
# Processing Record 30 of Set 10 | sergeyevka
# Processing Record 31 of Set 10 | kostyantynivka
# Processing Record 32 of Set 10 | pasni
# Processing Record 33 of Set 10 | young
# Processing Record 34 of Set 10 | maple creek
# Processing Record 35 of Set 10 | turan
# Processing Record 36 of Set 10 | caravelas
# Processing Record 37 of Set 10 | dhidhdhoo
# Processing Record 38 of Set 10 | yueyang
# Processing Record 39 of Set 10 | babstovo
# Processing Record 40 of Set 10 | rio grande
# Processing Record 41 of Set 10 | linqiong
# Processing Record 42 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 43 of Set 10 | touros
# Processing Record 44 of Set 10 | alegrete
# Processing Record 45 of Set 10 | khorixas
# Processing Record 46 of Set 10 | leshan
# Processing Record 47 of Set 10 | burica
# City not found. Skipping...
# Processing Record 48 of Set 10 | canberra
# Processing Record 49 of Set 10 | noyabrsk
# Processing Record 50 of Set 10 | sakakah
# Processing Record 1 of Set 11 | babu
# Processing Record 2 of Set 11 | taltal
# Processing Record 3 of Set 11 | vestmanna
# Processing Record 4 of Set 11 | bubaque
# Processing Record 5 of Set 11 | mujiayingzi
# Processing Record 6 of Set 11 | grand forks
# Processing Record 7 of Set 11 | dumka
# Processing Record 8 of Set 11 | ashqelon
# Processing Record 9 of Set 11 | the valley
# Processing Record 10 of Set 11 | mahina
# Processing Record 11 of Set 11 | muisne
# Processing Record 12 of Set 11 | yumen
# Processing Record 13 of Set 11 | guarapari
# Processing Record 14 of Set 11 | hvide sande
# Processing Record 15 of Set 11 | zyryanka
# Processing Record 16 of Set 11 | vostochnyy
# Processing Record 17 of Set 11 | kachiry
# Processing Record 18 of Set 11 | bangassou
# Processing Record 19 of Set 11 | atasu
# Processing Record 20 of Set 11 | norton shores
# Processing Record 21 of Set 11 | katsuura
# Processing Record 22 of Set 11 | atka
# City not found. Skipping...
# Processing Record 23 of Set 11 | zasheyek
# Processing Record 24 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 11 | doha
# Processing Record 26 of Set 11 | oskarshamn
# Processing Record 27 of Set 11 | ko samui
# Processing Record 28 of Set 11 | labuhan
# Processing Record 29 of Set 11 | hirara
# Processing Record 30 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 31 of Set 11 | erenhot
# Processing Record 32 of Set 11 | victor harbor
# Processing Record 33 of Set 11 | quiruvilca
# Processing Record 34 of Set 11 | filadelfia
# Processing Record 35 of Set 11 | thessalon
# Processing Record 36 of Set 11 | mildura
# Processing Record 37 of Set 11 | padang
# Processing Record 38 of Set 11 | melilla
# Processing Record 39 of Set 11 | orlik
# Processing Record 40 of Set 11 | orocue
# Processing Record 41 of Set 11 | arkhara
# Processing Record 42 of Set 11 | meadow lake
# Processing Record 43 of Set 11 | dauphin
# Processing Record 44 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 11 | khandbari
# Processing Record 46 of Set 11 | porto belo
# Processing Record 47 of Set 11 | fort walton beach
# Processing Record 48 of Set 11 | idrinskoye
# Processing Record 49 of Set 11 | najran
# Processing Record 50 of Set 11 | barguzin
# Processing Record 1 of Set 12 | marsh harbour
# Processing Record 2 of Set 12 | broken hill
# Processing Record 3 of Set 12 | narasannapeta
# Processing Record 4 of Set 12 | san patricio
# Processing Record 5 of Set 12 | watsa
# Processing Record 6 of Set 12 | ulaanbaatar
# Processing Record 7 of Set 12 | bonthe
# Processing Record 8 of Set 12 | puerto narino
# Processing Record 9 of Set 12 | henties bay
# Processing Record 10 of Set 12 | zakamensk
# Processing Record 11 of Set 12 | mount isa
# Processing Record 12 of Set 12 | ornskoldsvik
# Processing Record 13 of Set 12 | moree
# Processing Record 14 of Set 12 | trujillo
# Processing Record 15 of Set 12 | yatou
# Processing Record 16 of Set 12 | isabela
# Processing Record 17 of Set 12 | tual
# Processing Record 18 of Set 12 | tonantins
# Processing Record 19 of Set 12 | vanderhoof
# Processing Record 20 of Set 12 | port said
# Processing Record 21 of Set 12 | port macquarie
# Processing Record 22 of Set 12 | bodden town
# Processing Record 23 of Set 12 | pingliang
# Processing Record 24 of Set 12 | deder
# Processing Record 25 of Set 12 | kiunga
# Processing Record 26 of Set 12 | meulaboh
# Processing Record 27 of Set 12 | morant bay
# Processing Record 28 of Set 12 | puerto colombia
# Processing Record 29 of Set 12 | paamiut
# Processing Record 30 of Set 12 | morondava
# Processing Record 31 of Set 12 | lillooet
# Processing Record 32 of Set 12 | cleveland
# Processing Record 33 of Set 12 | nabire
# Processing Record 34 of Set 12 | sorong
# Processing Record 35 of Set 12 | soyo
# Processing Record 36 of Set 12 | tokonou
# Processing Record 37 of Set 12 | jiuquan
# Processing Record 38 of Set 12 | patiya
# Processing Record 39 of Set 12 | cochrane
# Processing Record 40 of Set 12 | tir pol
# City not found. Skipping...
# Processing Record 41 of Set 12 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 42 of Set 12 | jacareacanga
# Processing Record 43 of Set 12 | san quintin
# Processing Record 44 of Set 12 | chaohu
# Processing Record 45 of Set 12 | phangnga
# Processing Record 46 of Set 12 | collie
# Processing Record 47 of Set 12 | banff
# Processing Record 48 of Set 12 | canutama
# Processing Record 49 of Set 12 | kutum
# Processing Record 50 of Set 12 | san andres
# Processing Record 1 of Set 13 | gobabis
# Processing Record 2 of Set 13 | moerai
# Processing Record 3 of Set 13 | yeovil
# Processing Record 4 of Set 13 | samarai
# Processing Record 5 of Set 13 | salym
# Processing Record 6 of Set 13 | hobyo
# Processing Record 7 of Set 13 | owando
# Processing Record 8 of Set 13 | kazlu ruda
# Processing Record 9 of Set 13 | la libertad
# Processing Record 10 of Set 13 | lincoln
# Processing Record 11 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 12 of Set 13 | polis
# Processing Record 13 of Set 13 | flinders
# Processing Record 14 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 13 | nioro
# Processing Record 16 of Set 13 | villefranche-de-rouergue
# Processing Record 17 of Set 13 | muriwai beach
# Processing Record 18 of Set 13 | mecca
# Processing Record 19 of Set 13 | agva
# City not found. Skipping...
# Processing Record 20 of Set 13 | maibong
# Processing Record 21 of Set 13 | fernley
# Processing Record 22 of Set 13 | karratha
# Processing Record 23 of Set 13 | sayyan
# Processing Record 24 of Set 13 | tatarskaya kargala
# Processing Record 25 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 26 of Set 13 | sawtell
# Processing Record 27 of Set 13 | alofi
# Processing Record 28 of Set 13 | kieta
# Processing Record 29 of Set 13 | ordzhonikidze
# Processing Record 30 of Set 13 | qui nhon
# Processing Record 31 of Set 13 | porto torres
# Processing Record 32 of Set 13 | yarmouth
# Processing Record 33 of Set 13 | umm lajj
# Processing Record 34 of Set 13 | wesselsbron
# Processing Record 35 of Set 13 | den helder
# Processing Record 36 of Set 13 | alyangula
# Processing Record 37 of Set 13 | portland
# Processing Record 38 of Set 13 | silver city
# Processing Record 39 of Set 13 | puksoozero
# Processing Record 40 of Set 13 | akdepe
# Processing Record 41 of Set 13 | coari
# Processing Record 42 of Set 13 | totness
# Processing Record 43 of Set 13 | kjollefjord
# Processing Record 44 of Set 13 | ust-tsilma
# Processing Record 45 of Set 13 | halifax
# Processing Record 46 of Set 13 | celestun
# Processing Record 47 of Set 13 | dire
# Processing Record 48 of Set 13 | klaksvik
# Processing Record 49 of Set 13 | marawi
# Processing Record 50 of Set 13 | beyla
# Processing Record 1 of Set 14 | gorin
# Processing Record 2 of Set 14 | magadi
# Processing Record 3 of Set 14 | zermatt
# Processing Record 4 of Set 14 | yefira
# City not found. Skipping...
# Processing Record 5 of Set 14 | beyneu
# Processing Record 6 of Set 14 | cervo
# Processing Record 7 of Set 14 | santa maria
# Processing Record 8 of Set 14 | ovalle
# Processing Record 9 of Set 14 | bonga
# Processing Record 10 of Set 14 | el alto
# Processing Record 11 of Set 14 | osmena
# Processing Record 12 of Set 14 | rocha
# Processing Record 13 of Set 14 | maldonado
# Processing Record 14 of Set 14 | gijon
# Processing Record 15 of Set 14 | beya
# Processing Record 16 of Set 14 | pangody
# Processing Record 17 of Set 14 | acheng
# Processing Record 18 of Set 14 | westport
# Processing Record 19 of Set 14 | santa marta
# Processing Record 20 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 14 | mahanoro
# Processing Record 22 of Set 14 | zhukovskiy
# Processing Record 23 of Set 14 | camapua
# Processing Record 24 of Set 14 | yeniseysk
# Processing Record 25 of Set 14 | dubrovnik
# Processing Record 26 of Set 14 | almaznyy
# Processing Record 27 of Set 14 | tautira
# Processing Record 28 of Set 14 | finnsnes
# Processing Record 29 of Set 14 | suzhou
# Processing Record 30 of Set 14 | sola
# Processing Record 31 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 14 | kaseda
# Processing Record 33 of Set 14 | rawson
# Processing Record 34 of Set 14 | amantea
# Processing Record 35 of Set 14 | severodvinsk
# Processing Record 36 of Set 14 | sawakin
# Processing Record 37 of Set 14 | nador
# Processing Record 38 of Set 14 | kirkwall
# Processing Record 39 of Set 14 | play cu
# City not found. Skipping...
# Processing Record 40 of Set 14 | mikhaylovka
# Processing Record 41 of Set 14 | lowestoft
# Processing Record 42 of Set 14 | tilichiki
# Processing Record 43 of Set 14 | prainha
# Processing Record 44 of Set 14 | soavinandriana
# Processing Record 45 of Set 14 | quzhou
# Processing Record 46 of Set 14 | talakan
# Processing Record 47 of Set 14 | khani
# Processing Record 48 of Set 14 | krasnaya gora
# Processing Record 49 of Set 14 | charters towers
# Processing Record 50 of Set 14 | gravdal
# Processing Record 1 of Set 15 | pangnirtung
# Processing Record 2 of Set 15 | haimen
# Processing Record 3 of Set 15 | viramgam
# Processing Record 4 of Set 15 | shetpe
# Processing Record 5 of Set 15 | brandfort
# Processing Record 6 of Set 15 | hami
# Processing Record 7 of Set 15 | saint-pierre
# Processing Record 8 of Set 15 | lao cai
# Processing Record 9 of Set 15 | calella
# Processing Record 10 of Set 15 | shelburne
# Processing Record 11 of Set 15 | haines junction
# Processing Record 12 of Set 15 | punta de piedra
# Processing Record 13 of Set 15 | kraslava
# Processing Record 14 of Set 15 | hay river
# Processing Record 15 of Set 15 | poronaysk
# Processing Record 16 of Set 15 | byron bay
# Processing Record 17 of Set 15 | calvinia
# Processing Record 18 of Set 15 | dwarka
# Processing Record 19 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 15 | berbera
# Processing Record 21 of Set 15 | amuntai
# Processing Record 22 of Set 15 | jaguarao
# Processing Record 23 of Set 15 | oriximina
# Processing Record 24 of Set 15 | alenquer
# Processing Record 25 of Set 15 | saint-paul
# Processing Record 26 of Set 15 | balkanabat
# Processing Record 27 of Set 15 | kyra
# Processing Record 28 of Set 15 | jadu
# Processing Record 29 of Set 15 | claveria
# Processing Record 30 of Set 15 | sao raimundo nonato
# Processing Record 31 of Set 15 | staraya poltavka
# Processing Record 32 of Set 15 | vao
# Processing Record 33 of Set 15 | zdvinsk
# Processing Record 34 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 15 | fukue
# Processing Record 36 of Set 15 | pemangkat
# Processing Record 37 of Set 15 | half moon bay
# Processing Record 38 of Set 15 | banda aceh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Khatanga  71.97  102.50     15.82        96         100       21.99
# 1        Yulara -25.24  130.99     84.20        26          98       16.11
# 2  Punta Arenas -53.15  -70.92     55.40        54          75       25.28
# 3        Atuona  -9.80 -139.03     79.14        78           6       20.13
# 4          Lima -12.04  -77.03     71.60        68          20       10.29
# 5       Ushuaia -54.80  -68.30     50.00        61          75       20.80
# 6    Slave Lake  55.28 -114.77     15.80        85           1        6.93
# 7        Kodiak  57.79 -152.41     32.00        92          90        9.17
# 8      Merville  50.64    2.64     37.99        93           0        1.99
# 9         Lubao  14.92  120.55     77.00        83          75        4.70
#
#   Country                 Date Current Description
# 0      RU  2020-11-29 19:57:56     overcast clouds
# 1      AU  2020-11-29 19:57:56     overcast clouds
# 2      CL  2020-11-29 19:55:04       broken clouds
# 3      PF  2020-11-29 19:57:33           clear sky
# 4      PE  2020-11-29 19:53:36          few clouds
# 5      AR  2020-11-29 19:52:58       broken clouds
# 6      CA  2020-11-29 19:57:56           clear sky
# 7      US  2020-11-29 19:57:29     overcast clouds
# 8      FR  2020-11-29 19:57:56           clear sky
# 9      PH  2020-11-29 19:57:57       broken clouds

# %%
# Re-order columns in city_data_df
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Khatanga      RU  71.97  102.50     15.82        96         100
# 1        Yulara      AU -25.24  130.99     84.20        26          98
# 2  Punta Arenas      CL -53.15  -70.92     55.40        54          75
# 3        Atuona      PF  -9.80 -139.03     79.14        78           6
# 4          Lima      PE -12.04  -77.03     71.60        68          20
# 5       Ushuaia      AR -54.80  -68.30     50.00        61          75
# 6    Slave Lake      CA  55.28 -114.77     15.80        85           1
# 7        Kodiak      US  57.79 -152.41     32.00        92          90
# 8      Merville      FR  50.64    2.64     37.99        93           0
# 9         Lubao      PH  14.92  120.55     77.00        83          75
#
#    Wind Speed Current Description
# 0       21.99     overcast clouds
# 1       16.11     overcast clouds
# 2       25.28       broken clouds
# 3       20.13           clear sky
# 4       10.29          few clouds
# 5       20.80       broken clouds
# 6        6.93           clear sky
# 7        9.17     overcast clouds
# 8        1.99           clear sky
# 9        4.70       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
